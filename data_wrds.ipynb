# %%
import wrds
import pandas as pd

db = wrds.Connection(wrds_username="priyamvadadaga")
# Out:
# Loading library list...
# Done

# %%
db.describe_table('comp', 'names')
# Out:
# Approximately 44198 rows in comp.names.
#        name  nullable              type  \
# 0     gvkey      True        VARCHAR(6)
# 1      conm      True       VARCHAR(70)
# 2       tic      True        VARCHAR(8)
# 3     cusip      True       VARCHAR(20)
# 4       cik      True       VARCHAR(10)
# 5       sic      True        VARCHAR(4)
# 6     naics      True        VARCHAR(6)
# 7   gsubind      True        VARCHAR(8)
# 8      gind      True        VARCHAR(6)
# 9     year1      True  DOUBLE PRECISION
# 10    year2      True  DOUBLE PRECISION
#
#                                            comment
# 0                               Global Company Key
# 1                                     Company Name
# 2                                    Ticker Symbol
# 3                                            CUSIP
# 4                                       CIK Number
# 5            Standard Industry Classification Code
# 6      North American Industry Classification Code
# 7                               GIC Sub-Industries
# 8                                   GIC Industries
# 9   First Fiscal Year of Available Accounting Data
# 10   Last Fiscal Year of Available Accounting Data

# %%
names_query = """
    SELECT DISTINCT gvkey, tic AS ticker, conm AS company_name, gind, gsubind, sic, naics
    FROM comp.names
    WHERE tic IS NOT NULL
"""

names_df = db.raw_sql(names_query)

# filter: GICS sector 45 (Information Technology)
names_with_gind = names_df.dropna(subset=["gind"]).copy()
names_with_gind.loc[:,"gind_str"] = names_with_gind["gind"].astype(str)

tech_universe = names_with_gind[
    names_with_gind["gind_str"].str.startswith("45")
].drop(columns=["gind_str"]).drop_duplicates("gvkey")

# %%
mktcap_query = """
    WITH latest AS (
        SELECT gvkey, datadate, mkvalt, prcc_f, csho,
            ROW_NUMBER() OVER (
                PARTITION BY gvkey
                ORDER BY datadate DESC
            ) AS rn
        FROM comp.funda
        WHERE indfmt = 'INDL' AND datafmt = 'STD' AND popsrc = 'D' AND consol = 'C'
    )
    SELECT gvkey, datadate, mkvalt, prcc_f, csho
    FROM latest
    WHERE rn = 1
"""

mktcap_df = db.raw_sql(mktcap_query)

# %%
import numpy as np

mktcap_df.loc[:,"market_cap"] = mktcap_df["mkvalt"]
missing_mask = mktcap_df["market_cap"].isna()
mktcap_df.loc[missing_mask, "market_cap"] = (
    mktcap_df.loc[missing_mask, "prcc_f"] * mktcap_df.loc[missing_mask, "csho"]
)

mktcap_df = mktcap_df.dropna(subset=["market_cap"])

# %%
tech_with_mktcap = tech_universe.merge(mktcap_df[["gvkey", "market_cap"]], on="gvkey", how="left")
tech_with_mktcap = tech_with_mktcap.dropna(subset=["market_cap"])

tech_sorted = tech_with_mktcap.sort_values("market_cap", ascending=False)
print("Tech names with size info:", len(tech_sorted))
# Out:
# Tech names with size info: 4503

# %%
top_tech = tech_sorted.head(20)

# %%
top_tech
# Out:
#        gvkey ticker                 company_name    gind   gsubind   sic  \
# 1358  001690   AAPL                    APPLE INC  452020  45202030  3663
# 3865  012141   MSFT               MICROSOFT CORP  451030  45103020  7372
# 4699  117768   NVDA                  NVIDIA CORP  453010  45301020  3674
# 1189  201395    TSM  TAIWAN SEMICONDUCTOR MFG CO  453010  45301020  3674
# 799   180711   AVGO                 BROADCOM INC  453010  45301020  3674
# 4640  012142   ORCL                  ORACLE CORP  451030  45103020  7372
# 2626  157855    CRM               SALESFORCE INC  451030  45103010  7372
# 3141  103487    SAP                       SAP SE  451030  45103010  7372
# 3780  061214   ASML              ASML HOLDING NV  453010  45301010  3559
# 2955  020779   CSCO            CISCO SYSTEMS INC  452010  45201020  3576
# 2169  012540   ADBE                    ADOBE INC  451030  45103010  7370
# 1554  027928   INTU                   INTUIT INC  451030  45103010  7372
# 2323  171007    NOW               SERVICENOW INC  451030  45103020  7372
# 3768  006066    IBM  INTL BUSINESS MACHINES CORP  451020  45102010  7370
# 4671  001161    AMD       ADVANCED MICRO DEVICES  453010  45301020  3674
# 473   001704   AMAT        APPLIED MATERIALS INC  453010  45301010  3559
# 804   024800   QCOM                 QUALCOMM INC  453010  45301020  3674
# 1988  036910   PLTR       PALANTIR TECHNOLOG INC  451030  45103010  7370
# 2687  010499    TXN        TEXAS INSTRUMENTS INC  453010  45301020  3674
# 648   143357    ACN                ACCENTURE PLC  451020  45102010  8742
#
#        naics     market_cap
# 1358  334220   3761715.1938
# 3865  513210     3697745.94
# 4699  334413     2938953.39
# 1189  334413  1024291.16703
# 799   334413      795542.22
# 4640  513210      464642.71
# 2626  513210       328715.4
# 3141  513210   287225.87769
# 3780  333242   272577.27472
# 2955  334118       269596.8
# 2169  518210      227525.13
# 1554  513210    219152.5518
# 2323  513210    218900.9984
# 3768  518210    203626.3307
# 4671  334413      195921.38
# 473   333242    185697.2502
# 804   334413      178670.64
# 1988  519130    176883.0659
# 2687  334413      170821.61
# 648   541611    161663.9043

# %%
import os

UNIVERSE_PATH = "data/universe"
os.makedirs(UNIVERSE_PATH, exist_ok=True)

TOP_TECH_PARQUET = os.path.join(UNIVERSE_PATH, "tech_universe_top20.parquet")

top_tech.to_parquet(TOP_TECH_PARQUET, index=False)
print(f"Saved tech universe to {TOP_TECH_PARQUET}")
# Out:
# Saved tech universe to data/universe/tech_universe_top20.parquet

# %%
top_tech = pd.read_parquet("data/universe/tech_universe_top20.parquet")

link_query = """
    SELECT DISTINCT companyid, gvkey, ticker, companyname
    FROM ciq.wrds_ciqsymbol_primary
    WHERE gvkey IS NOT NULL AND companyid IS NOT NULL
"""
ciq_links = db.raw_sql(link_query)

ciq_links.loc[:, "gvkey"] = ciq_links["gvkey"].astype(str)
top_tech.loc[:, "gvkey"] = top_tech["gvkey"].astype(str)

top_tech_with_ciq = top_tech.merge(
    ciq_links.rename(columns={
        "companyid": "ciq_company_id",
        "companyname": "ciq_company_name"
    }),
    on="gvkey",
    how="inner"
)

top_tech_with_ciq = top_tech_with_ciq.dropna(subset=["ciq_company_id"])
top_tech_with_ciq = top_tech_with_ciq.drop_duplicates("ciq_company_id")

print("Top tech with CIQ IDs:", len(top_tech_with_ciq))
# Out:
# Top tech with CIQ IDs: 20

# %%
TECH_CIQ_PARQUET = os.path.join(UNIVERSE_PATH, "tech_universe_top20_with_ciq.parquet")
top_tech_with_ciq.to_parquet(TECH_CIQ_PARQUET, index=False)
print("Saved:", TECH_CIQ_PARQUET)
# Out:
# Saved: data/universe/tech_universe_top20_with_ciq.parquet

# %%
top_tech_with_ciq = pd.read_parquet(TECH_CIQ_PARQUET)
top_tech_with_ciq.loc[:, "ciq_company_id"] = top_tech_with_ciq["ciq_company_id"].astype(int)
company_ids = top_tech_with_ciq["ciq_company_id"].tolist()

# %%
ids = ", ".join(str(cid) for cid in company_ids)

sql_query = f"""
SELECT 
    d.companyid, d.transcriptid, d.headline,
    d.mostimportantdateutc, d.mostimportanttimeutc,
    d.keydeveventtypeid, d.keydeveventtypename,
    d.companyname AS detail_companyname,
    d.transcriptcollectiontypeid, p.transcriptcomponenttypeid,
    p.transcriptcomponenttypename, p.transcriptpersonid,
    p.transcriptpersonname, p.proid, p.companyofperson,
    p.speakertypeid, p.speakertypename,
    p.componentorder,
    p.componenttextpreview,
    c.componenttext
FROM ciq.wrds_transcript_detail d
JOIN ciq.wrds_transcript_person p ON d.transcriptid = p.transcriptid
JOIN ciq.ciqtranscriptcomponent c ON p.transcriptcomponentid = c.transcriptcomponentid
WHERE d.companyid IN ({ids})
  AND d.mostimportantdateutc >= (CURRENT_DATE - INTERVAL '1 year')
  AND d.keydeveventtypename = 'Earnings Calls'
ORDER BY d.companyid, d.transcriptid, p.componentorder;
"""

# %%
raw_segments = db.raw_sql(sql_query)
print("Transcript segments:", len(raw_segments))
# Out:
# Transcript segments: 10255

# %%
raw_segments.columns
# Out:
# Index(['companyid', 'transcriptid', 'headline', 'mostimportantdateutc',
#        'mostimportanttimeutc', 'keydeveventtypeid', 'keydeveventtypename',
#        'detail_companyname', 'transcriptcollectiontypeid',
#        'transcriptcomponenttypeid', 'transcriptcomponenttypename',
#        'transcriptpersonid', 'transcriptpersonname', 'proid',
#        'companyofperson', 'speakertypeid', 'speakertypename', 'componentorder',
#        'componenttextpreview', 'componenttext'],
#       dtype='object')

# %%
raw_segments.loc[:,"timestamp"] = (
    raw_segments["mostimportantdateutc"].astype(str) + " " +
    raw_segments["mostimportanttimeutc"].astype(str)
)

# unique calls by timestamp
unique_call_counts = (
    raw_segments.groupby(["companyid", "detail_companyname"])["timestamp"]
    .nunique()
    .reset_index(name="unique_timestamp_count")
)

unique_call_counts
# Out:
#      companyid                                 detail_companyname  \
# 0      19691.0                                Cisco Systems, Inc.
# 1      21171.0                                        Intuit Inc.
# 2      21835.0                              Microsoft Corporation
# 3      22247.0                                 Oracle Corporation
# 4      24321.0                                         Adobe Inc.
# 5      24937.0                                         Apple Inc.
# 6      32307.0                                 NVIDIA Corporation
# 7      33493.0                              QUALCOMM Incorporated
# 8     112350.0        International Business Machines Corporation
# 9     122917.0                                   Salesforce, Inc.
# 10    126475.0                                             SAP SE
# 11    140283.0                     Texas Instruments Incorporated
# 12    168864.0                       Advanced Micro Devices, Inc.
# 13    251230.0                            Applied Materials, Inc.
# 14    380075.0  Taiwan Semiconductor Manufacturing Company Lim...
# 15    388904.0                                  ASML Holding N.V.
# 16    972190.0                                      Accenture plc
# 17  22967487.0                                   ServiceNow, Inc.
# 18  25016048.0                                      Broadcom Inc.
# 19  43580005.0                         Palantir Technologies Inc.
#
#     unique_timestamp_count
# 0                        3
# 1                        4
# 2                        4
# 3                        4
# 4                        4
# 5                        4
# 6                        4
# 7                        4
# 8                        4
# 9                        4
# 10                       4
# 11                       4
# 12                       4
# 13                       3
# 14                       4
# 15                       7
# 16                       4
# 17                       4
# 18                       4
# 19                       4

# %%
segments_enriched = raw_segments.merge(
    top_tech_with_ciq,
    left_on="companyid",
    right_on="ciq_company_id",
    how="left"
)

call_section = segments_enriched.loc[:,[
    "companyid",
    "company_name",
    "market_cap",
    "transcriptid",
    "headline",
    "mostimportantdateutc",
    "mostimportanttimeutc",
    "keydeveventtypeid",
    "keydeveventtypename",
    "transcriptcollectiontypeid",
    "transcriptcomponenttypename",
    "transcriptpersonname",
    "speakertypename",
    "componentorder",
    "componenttext",
]]

call_section.loc[:,"segment_id"] = (call_section["transcriptid"].astype(str) + "_" + call_section["componentorder"].astype(str))
call_section = call_section.reset_index(drop=True)
call_section["segment_idx"] = call_section.index

# %%
call_section["mostimportantdateutc"] = pd.to_datetime(call_section["mostimportantdateutc"], errors="coerce").astype("datetime64[ns]")
call_section.loc[:,"call_year"] = call_section["mostimportantdateutc"].dt.year
call_section.loc[:,"call_quarter"] = "Q" + call_section["mostimportantdateutc"].dt.quarter.astype(str)

call_section.loc[:,"call_period"] = (call_section["call_year"].astype(str) + " " + call_section["call_quarter"])

# %%
import re

def clean_component_text(text: str) -> str:
    if not isinstance(text, str): return ""
    t = text.replace("\r", " ").strip()
    t = re.sub(r"\s+", " ", t)
    return t

call_section.loc[:,"clean_text"] = call_section["componenttext"].apply(clean_component_text)

# %%
import os
import pandas as pd

CORPUS_PATH = "data/corpus"
os.makedirs(CORPUS_PATH, exist_ok=True)

CALL_SECTION_PARQUET = os.path.join(CORPUS_PATH, "tech_call_sections.parquet")
call_section.to_parquet(CALL_SECTION_PARQUET, index=False)
print("Saved:", CALL_SECTION_PARQUET)
# Out:
# Saved: data/corpus/tech_call_sections.parquet

# %%
call_section["call_datetime"] = pd.to_datetime(
    call_section["mostimportantdateutc"].astype(str) + " " + call_section["mostimportanttimeutc"].astype(str),
    errors="coerce",
)

# %%
call_level = (
    call_section
    .sort_values(["companyid", "transcriptid", "componentorder"])
    .groupby(["companyid", "company_name", "market_cap", "transcriptid", "headline", "call_datetime"], as_index=False)
    .agg({"componenttext": lambda parts: "\n".join(parts)})
)

# %%
call_level = call_level.rename(columns={"componenttext": "full_transcript"})
call_level["call_date"] = (pd.to_datetime(call_level["call_datetime"], errors="coerce").astype("datetime64[ns]"))
call_level["call_year"] = call_level["call_date"].dt.year
call_level["call_quarter"] = "Q" + call_level["call_date"].dt.quarter.astype(str)
call_level["call_period"] = (call_level["call_year"].astype(str) + " " + call_level["call_quarter"])

EARNINGS_CALL_PARQUET = os.path.join(CORPUS_PATH, "tech_earnings_calls.parquet")
call_level.to_parquet(EARNINGS_CALL_PARQUET, index=False)
print("Saved:", EARNINGS_CALL_PARQUET)
# Out:
# Saved: data/corpus/tech_earnings_calls.parquet
# /var/folders/m6/86n33n2x3b5_jv4lcwk88kb80000gn/T/ipykernel_23923/2394348975.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   call_level["call_date"] = (pd.to_datetime(call_level["call_datetime"], errors="coerce").astype("datetime64[ns]"))
# /var/folders/m6/86n33n2x3b5_jv4lcwk88kb80000gn/T/ipykernel_23923/2394348975.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   call_level["call_year"] = call_level["call_date"].dt.year
# /var/folders/m6/86n33n2x3b5_jv4lcwk88kb80000gn/T/ipykernel_23923/2394348975.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   call_level["call_quarter"] = "Q" + call_level["call_date"].dt.quarter.astype(str)
# /var/folders/m6/86n33n2x3b5_jv4lcwk88kb80000gn/T/ipykernel_23923/2394348975.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   call_level["call_period"] = (call_level["call_year"].astype(str) + " " + call_level["call_quarter"])

# %%
call_section.columns
# Out:
# Index(['companyid', 'company_name', 'market_cap', 'transcriptid', 'headline',
#        'mostimportantdateutc', 'mostimportanttimeutc', 'keydeveventtypeid',
#        'keydeveventtypename', 'transcriptcollectiontypeid',
#        'transcriptcomponenttypename', 'transcriptpersonname',
#        'speakertypename', 'componentorder', 'componenttext', 'segment_id',
#        'segment_idx', 'call_year', 'call_quarter', 'call_period', 'clean_text',
#        'call_datetime'],
#       dtype='object')

# %%
call_section
# Out:
#         companyid            company_name   market_cap  transcriptid  \
# 0         19691.0       CISCO SYSTEMS INC     269596.8     3372444.0
# 1         19691.0       CISCO SYSTEMS INC     269596.8     3372444.0
# 2         19691.0       CISCO SYSTEMS INC     269596.8     3372444.0
# 3         19691.0       CISCO SYSTEMS INC     269596.8     3372444.0
# 4         19691.0       CISCO SYSTEMS INC     269596.8     3372444.0
# ...           ...                     ...          ...           ...
# 10250  43580005.0  PALANTIR TECHNOLOG INC  176883.0659     3576741.0
# 10251  43580005.0  PALANTIR TECHNOLOG INC  176883.0659     3576741.0
# 10252  43580005.0  PALANTIR TECHNOLOG INC  176883.0659     3576741.0
# 10253  43580005.0  PALANTIR TECHNOLOG INC  176883.0659     3576741.0
# 10254  43580005.0  PALANTIR TECHNOLOG INC  176883.0659     3576741.0
#
#                                                 headline mostimportantdateutc  \
# 0      Cisco Systems, Inc., Q2 2025 Earnings Call, Fe...           2025-02-12
# 1      Cisco Systems, Inc., Q2 2025 Earnings Call, Fe...           2025-02-12
# 2      Cisco Systems, Inc., Q2 2025 Earnings Call, Fe...           2025-02-12
# 3      Cisco Systems, Inc., Q2 2025 Earnings Call, Fe...           2025-02-12
# 4      Cisco Systems, Inc., Q2 2025 Earnings Call, Fe...           2025-02-12
# ...                                                  ...                  ...
# 10250  Palantir Technologies Inc., Q3 2025 Earnings C...           2025-11-03
# 10251  Palantir Technologies Inc., Q3 2025 Earnings C...           2025-11-03
# 10252  Palantir Technologies Inc., Q3 2025 Earnings C...           2025-11-03
# 10253  Palantir Technologies Inc., Q3 2025 Earnings C...           2025-11-03
# 10254  Palantir Technologies Inc., Q3 2025 Earnings C...           2025-11-03
#
#       mostimportanttimeutc  keydeveventtypeid keydeveventtypename  \
# 0                 21:30:00               48.0      Earnings Calls
# 1                 21:30:00               48.0      Earnings Calls
# 2                 21:30:00               48.0      Earnings Calls
# 3                 21:30:00               48.0      Earnings Calls
# 4                 21:30:00               48.0      Earnings Calls
# ...                    ...                ...                 ...
# 10250             22:00:00               48.0      Earnings Calls
# 10251             22:00:00               48.0      Earnings Calls
# 10252             22:00:00               48.0      Earnings Calls
# 10253             22:00:00               48.0      Earnings Calls
# 10254             22:00:00               48.0      Earnings Calls
#
#        transcriptcollectiontypeid  ... speakertypename componentorder  \
# 0                               7  ...        Operator              0
# 1                               7  ...      Executives              1
# 2                               7  ...      Executives              2
# 3                               7  ...        Operator              3
# 4                               7  ...        Analysts              4
# ...                           ...  ...             ...            ...
# 10250                           2  ...      Executives             17
# 10251                           2  ...      Executives             18
# 10252                           2  ...      Executives             19
# 10253                           2  ...      Executives             20
# 10254                           2  ...      Executives             21
#
#                                            componenttext    segment_id  \
# 0                                            [Audio Gap]   3372444.0_0
# 1      [Audio Gap]
# Demand growth in our Nexus portfol...   3372444.0_1
# 2      Thank you, And I just want to remind analysts ...   3372444.0_2
# 3                          Ben Reitzes, Melius Research.   3372444.0_3
# 4      Congrats on the quarter. It's good to see you ...   3372444.0_4
# ...                                                  ...           ...
# 10250  Ryan is our best at being a wonderful -- I'll ...  3576741.0_17
# 10251  I'll make the mistake of trying to follow Alex...  3576741.0_18
# 10252  Thank you. Alex, as always, we have a lot of i...  3576741.0_19
# 10253  We're rocking along. Please turn on the conven...  3576741.0_20
# 10254    Thank you. That concludes Q&A for today's call.  3576741.0_21
#
#       segment_idx call_year  call_quarter  call_period  \
# 0               0      2025            Q1      2025 Q1
# 1               1      2025            Q1      2025 Q1
# 2               2      2025            Q1      2025 Q1
# 3               3      2025            Q1      2025 Q1
# 4               4      2025            Q1      2025 Q1
# ...           ...       ...           ...          ...
# 10250       10250      2025            Q4      2025 Q4
# 10251       10251      2025            Q4      2025 Q4
# 10252       10252      2025            Q4      2025 Q4
# 10253       10253      2025            Q4      2025 Q4
# 10254       10254      2025            Q4      2025 Q4
#
#                                               clean_text       call_datetime
# 0                                            [Audio Gap] 2025-02-12 21:30:00
# 1      [Audio Gap] Demand growth in our Nexus portfol... 2025-02-12 21:30:00
# 2      Thank you, And I just want to remind analysts ... 2025-02-12 21:30:00
# 3                          Ben Reitzes, Melius Research. 2025-02-12 21:30:00
# 4      Congrats on the quarter. It's good to see you ... 2025-02-12 21:30:00
# ...                                                  ...                 ...
# 10250  Ryan is our best at being a wonderful -- I'll ... 2025-11-03 22:00:00
# 10251  I'll make the mistake of trying to follow Alex... 2025-11-03 22:00:00
# 10252  Thank you. Alex, as always, we have a lot of i... 2025-11-03 22:00:00
# 10253  We're rocking along. Please turn on the conven... 2025-11-03 22:00:00
# 10254    Thank you. That concludes Q&A for today's call. 2025-11-03 22:00:00
#
# [10255 rows x 22 columns]
